# %%
import pandas as pd

# %%
df=pd.read_csv("iris.csv")
df2=df

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
import numpy as np
df.loc[2,'Species']=np.nan
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        149 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
pd.to_numeric(df['Species'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\anaconda\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Iris-setosa"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_43488\3361272994.py in <module>
# ----> 1 pd.to_numeric(df['Species'])
#
# D:\anaconda\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     182         coerce_numeric = errors not in ("ignore", "raise")
#     183         try:
# --> 184             values, _ = lib.maybe_convert_numeric(
#     185                 values, set(), coerce_numeric=coerce_numeric
#     186             )
#
# ...

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
for i in df.columns:
    print(i,"  ",df[i].dtype)
# Out:
# Id    int64
# SepalLengthCm    float64
# SepalWidthCm    float64
# PetalLengthCm    float64
# PetalWidthCm    float64
# Species    object

# %%
col=pd.get_dummies(df['Species'])
df2=df
df2=pd.concat([df2,col],axis=1)
df2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  Iris-setosa  Iris-versicolor  Iris-virginica
# 0       Iris-setosa            1                0               0
# ...

# %%
df3=df
df3.drop(columns=["Id","SepalLengthCm"])
df3.replace(to_replace="Iris-setosa",value="Iris-petosa")
df3
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
myscalar=MinMaxScaler()
# StandardScaler also u can use
arr=[]
for i in df.columns:
    if(df[i].dtype in ['int64','float64']):
        arr.append(i);
df[arr]=myscalar.fit_transform(df[arr])
df
# Out:
#            Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    0.000000       0.222222      0.625000       0.067797      0.041667
# 1    0.006711       0.166667      0.416667       0.067797      0.041667
# 2    0.013423       0.111111      0.500000       0.050847      0.041667
# 3    0.020134       0.083333      0.458333       0.084746      0.041667
# 4    0.026846       0.194444      0.666667       0.067797      0.041667
# ..        ...            ...           ...            ...           ...
# 145  0.973154       0.666667      0.416667       0.711864      0.916667
# 146  0.979866       0.555556      0.208333       0.677966      0.750000
# 147  0.986577       0.611111      0.416667       0.711864      0.791667
# 148  0.993289       0.527778      0.583333       0.745763      0.916667
# 149  1.000000       0.444444      0.416667       0.694915      0.708333
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# ...

# %%
# assignment 2
# norm on any column
myscaler=StandardScaler()
arr2=['SepalLengthCm']

df[arr2]=myscaler.fit_transform(df[arr2])
df
# Out:
#            Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    0.000000      -0.900681      0.625000       0.067797      0.041667
# 1    0.006711      -1.143017      0.416667       0.067797      0.041667
# 2    0.013423      -1.385353      0.500000       0.050847      0.041667
# 3    0.020134      -1.506521      0.458333       0.084746      0.041667
# 4    0.026846      -1.021849      0.666667       0.067797      0.041667
# ..        ...            ...           ...            ...           ...
# 145  0.973154       1.038005      0.416667       0.711864      0.916667
# 146  0.979866       0.553333      0.208333       0.677966      0.750000
# 147  0.986577       0.795669      0.416667       0.711864      0.791667
# 148  0.993289       0.432165      0.583333       0.745763      0.916667
# 149  1.000000       0.068662      0.416667       0.694915      0.708333
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# ...

# %%
df.shape
# Out:
# (150, 6)

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species  \
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
#      (1, SepalLengthCm)
# ...

# %%
df2.loc[2,"SepalLengthCm"]=90
df2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3           90.0           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  (1, SepalLengthCm)
# 0       Iris-setosa                  90
# 1       Iris-setosa                  90
# ...

# %%
# for i in df.index:   for rows
for i in df.columns:
    print(df[i].dtype)
# Out:
# int64
# float64
# float64
# float64
# float64
# object
# int64

# %%
df['SepalLengthCm']=df['SepalLengthCm'].astype(int)
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1              5           3.5            1.4           0.2
# 1      2              4           3.0            1.4           0.2
# 2      3             90           3.2            1.3           0.2
# 3      4              4           3.1            1.5           0.2
# 4      5              5           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146              6           3.0            5.2           2.3
# 146  147              6           2.5            5.0           1.9
# 147  148              6           3.0            5.2           2.0
# 148  149              6           3.4            5.4           2.3
# 149  150              5           3.0            5.1           1.8
#
#             Species  (1, SepalLengthCm)
# 0       Iris-setosa                  90
# 1       Iris-setosa                  90
# ...

# %%
df['SepalLengthCm'].median()
# Out:
# 5.0

# %%
mycol=pd.get_dummies(df['Species'])
df=pd.concat([df,mycol],axis=1)
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1              5           3.5            1.4           0.2
# 1      2              4           3.0            1.4           0.2
# 2      3             90           3.2            1.3           0.2
# 3      4              4           3.1            1.5           0.2
# 4      5              5           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146              6           3.0            5.2           2.3
# 146  147              6           2.5            5.0           1.9
# 147  148              6           3.0            5.2           2.0
# 148  149              6           3.4            5.4           2.3
# 149  150              5           3.0            5.1           1.8
#
#             Species  (1, SepalLengthCm)  Iris-setosa  Iris-versicolor  \
# 0       Iris-setosa                  90            1                0
# ...

# %%
#data transfo
df['SepalLengthCm']=df['SepalLengthCm']*0.5
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            2.5           3.5            1.4           0.2
# 1      2            2.0           3.0            1.4           0.2
# 2      3           45.0           3.2            1.3           0.2
# 3      4            2.0           3.1            1.5           0.2
# 4      5            2.5           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            3.0           3.0            5.2           2.3
# 146  147            3.0           2.5            5.0           1.9
# 147  148            3.0           3.0            5.2           2.0
# 148  149            3.0           3.4            5.4           2.3
# 149  150            2.5           3.0            5.1           1.8
#
#             Species  (1, SepalLengthCm)  Iris-setosa  Iris-versicolor  \
# 0       Iris-setosa                  90            1                0
# ...

# %%
# minmax
df['minmaxSepalLengthCm']=(df['SepalLengthCm']-df['SepalLengthCm'].min())/(df['SepalLengthCm'].max()-df['SepalLengthCm'].min())

# %%
# zscore
df['zscoreSepalLengthCm']=(df['SepalLengthCm']-df['SepalLengthCm'].mean())/(df['SepalLengthCm'].std())

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            2.5           3.5            1.4           0.2
# 1      2            2.0           3.0            1.4           0.2
# 2      3           45.0           3.2            1.3           0.2
# 3      4            2.0           3.1            1.5           0.2
# 4      5            2.5           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            3.0           3.0            5.2           2.3
# 146  147            3.0           2.5            5.0           1.9
# 147  148            3.0           3.0            5.2           2.0
# 148  149            3.0           3.4            5.4           2.3
# 149  150            2.5           3.0            5.1           1.8
#
#             Species  (1, SepalLengthCm)  Iris-setosa  Iris-versicolor  \
# 0       Iris-setosa                  90            1                0
# ...

# %%
outl=df['zscoreSepalLengthCm']>3
outl
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: zscoreSepalLengthCm, Length: 150, dtype: bool

# %%
grouped = df.groupby('Species')
for gname,gdata in grouped:
    print(gname)
    print("\n")
    print(gdata)
# Out:
# Iris-setosa
#
#
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
info=df.groupby('Species')["Iris-versicolor"].describe()
print(info)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35640\821328050.py in <module>
# ----> 1 info=df.groupby('Species')["Iris-versicolor"].describe()
#       2 print(info)
#
# D:\anaconda\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1336                 stacklevel=find_stack_level(),
#    1337             )
# -> 1338         return super().__getitem__(key)
#    1339
#    1340     def _gotitem(self, key, ndim: int, subset=None):
#
# D:\anaconda\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     248         else:
#     249             if key not in self.obj:
# --> 250                 raise KeyError(f"Column not found: {key}")
#     251             subset = self.obj[key]
#     252             ndim = subset.ndim
#
# KeyError: 'Column not found: Iris-versicolor'

# %%
#dealing with missing values

# %%
df4=pd.read_csv('titanic.csv')
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
for x in df['Age']:
    if(x.dtype!=NaN):
        print(x)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# D:\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df4['Cabin'].fillna("mycabin")
# Out:
# 0      mycabin
# 1          C85
# 2      mycabin
# 3         C123
# 4      mycabin
#         ...
# 886    mycabin
# 887        B42
# 888    mycabin
# 889       C148
# 890    mycabin
# Name: Cabin, Length: 891, dtype: object

# %%
df4.fillna("ok")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
mn=df4['Age'].mean()
df4['Age'].fillna(mn)
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
arr=['fare']
from sklearn.preprocessing import StandardScaler
myscaler=StandardScaler()

df4[arr]=myscaler.fit_transform(df4[arr])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35640\2579730306.py in <module>
#       3 myscaler=StandardScaler()
#       4
# ----> 5 df4[arr]=myscaler.fit_transform(df4[arr])
#
# D:\anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# D:\anaconda\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# ...
